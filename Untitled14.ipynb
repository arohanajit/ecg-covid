# %% [markdown]
# <a href="https://colab.research.google.com/github/arohanajit/ecg-covid/blob/main/Untitled14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as Fl
from torchsummary import summary
from torch import optim
from torch.utils.data import DataLoader, TensorDataset, random_split
from torch.utils.data.sampler import SubsetRandomSampler
from torchvision.datasets import ImageFolder
import torchvision.transforms as transforms
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score
from tqdm import tqdm_notebook
import torchvision
import shutil
train_on_gpu = torch.cuda.is_available()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(train_on_gpu)
# Out:
# True

# %%
# !git clone https://arohanajit:TXhqMLvKoeiUtMy_Xtrz@gitlab.com/arohanajit/ecg-covid.git
# !mkdir data
# !unzip ecg-covid/ecg.zip -d data/
shutil.rmtree("data/ECG Images of Myocardial Infarction Patients (77)")
shutil.rmtree("data/ECG Images of Patient that have abnormal heart beats (548)")
shutil.rmtree("data/ECG Images of Patient that have History of MI (203)")
shutil.rmtree("ecg-covid")
# Out:
# Cloning into 'ecg-covid'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 9 (delta 1), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (9/9), done.
# Archive:  ecg-covid/ecg.zip
#    creating: data/Normal Person ECG Images (859)/
#   inflating: data/Normal Person ECG Images (859)/Normal (43).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (322).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (7).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (160).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (403).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (797).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (241).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (124).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (205).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (599).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (520).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (601).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (106).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (61).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (502).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (340).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (421).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (142).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (698).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (304).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (223).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (779).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (700).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (25).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (52).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (250).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (412).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (331).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (214).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (689).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (133).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (610).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (16).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (70).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (115).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (430).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (511).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (788).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (232).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (151).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (313).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (34).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (249).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (168).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (807).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (483).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (645).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (564).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (726).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (447).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (609).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (285).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (528).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (366).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (843).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (681).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (87).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (762).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (267).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (429).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (348).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (186).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (663).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (825).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (744).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (69).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (582).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (627).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (465).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (384).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (708).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (546).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (780).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (339).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (177).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (258).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (735).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (573).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (492).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (816).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (654).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (375).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (537).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (456).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (294).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (618).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (96).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (771).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (852).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (690).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (195).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (519).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (357).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (276).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (438).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (591).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (753).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (78).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (672).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (834).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (555).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (717).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (393).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (636).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (474).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (159).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (524).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (362).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (605).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (281).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (443).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (209).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (83).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (128).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (560).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (722).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (47).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (641).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (803).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (245).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (407).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (326).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (164).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (380).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (29).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (704).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (542).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (461).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (623).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (227).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (146).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (308).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (65).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (740).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (821).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (425).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (263).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (182).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (506).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (344).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (452).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (290).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (614).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (533).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (371).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (137).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (218).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (92).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (812).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (650).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (731).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (56).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (173).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (335).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (254).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (416).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (632).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (470).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (38).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (713).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (551).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (317).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (155).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (236).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (830).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (119).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (74).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (353).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (515).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (191).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (434).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (272).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (685).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (847).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (766).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (210).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (12).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (289).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (568).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (487).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (649).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (784).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (388).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (30).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (469).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (586).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (748).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (667).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (829).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (111).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (775).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (694).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (300).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (856).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (298).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (21).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (379).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (658).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (496).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (102).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (739).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (577).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (793).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (3).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (478).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (559).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (397).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (199).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (120).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (838).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (676).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (201).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (595).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (757).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (225).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (144).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (306).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (621).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (540).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (27).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (702).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (423).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (261).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (504).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (180).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (342).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (108).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (63).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (243).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (799).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (405).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (9).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (324).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (162).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (801).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (45).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (720).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (603).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (441).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (360).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (522).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (126).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (81).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (207).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (315).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (153).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (234).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (711).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (36).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (630).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (351).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (513).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (432).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (270).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (72).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (117).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (171).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (333).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (252).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (414).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (54).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (810).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (531).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (18).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (612).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (450).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (216).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (90).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (135).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (548).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (386).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (629).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (467).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (782).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (584).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (746).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (665).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (827).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (269).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (188).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (728).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (566).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (485).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (809).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (647).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (764).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (89).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (845).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (683).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (449).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (287).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (368).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (10).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (476).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (638).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (557).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (395).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (719).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (1).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (791).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (836).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (674).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (593).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (755).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (197).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (359).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (278).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (656).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (100).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (818).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (494).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (737).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (575).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (179).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (692).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (854).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (98).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (773).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (377).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (539).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (458).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (296).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (661).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (823).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (742).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (67).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (580).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (346).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (508).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (184).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (427).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (265).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (148).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (229).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (706).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (382).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (544).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (463).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (625).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (841).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (85).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (760).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (526).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (364).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (283).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (607).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (445).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (166).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (328).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (247).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (409).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (562).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (49).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (724).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (643).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (805).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (481).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (76).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (751).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (670).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (832).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (274).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (436).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (355).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (193).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (517).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (238).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (319).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (157).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (634).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (472).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (391).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (715).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (553).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (94).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (850).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (139).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (454).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (616).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (292).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (535).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (373).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (418).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (256).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (175).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (337).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (814).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (490).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (652).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (571).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (733).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (58).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (113).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (669).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (588).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (32).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (311).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (230).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (786).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (14).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (687).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (849).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (131).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (768).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (212).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (489).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (50).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (410).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (759).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (597).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (203).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (122).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (678).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (41).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (399).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (795).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (401).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (320).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (5).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (23).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (221).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (777).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (302).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (696).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (858).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (140).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (579).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (104).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (498).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (500).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (512).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (350).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (431).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (71).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (116).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (35).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (710).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (233).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (789).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (314).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (152).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (17).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (530).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (611).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (215).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (134).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (53).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (413).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (251).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (170).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (332).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (440).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (602).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (521).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (125).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (206).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (80).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (800).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (44).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (161).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (323).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (8).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (242).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (404).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (798).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (620).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (26).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (701).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (305).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (699).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (143).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (224).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (107).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (62).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (341).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (503).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (422).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (260).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (673).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (835).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (79).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (754).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (592).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (358).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (196).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (439).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (277).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (790).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (394).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (718).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (556).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (475).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (637).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (853).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (691).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (772).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (97).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (538).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (376).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (619).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (295).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (457).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (178).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (259).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (574).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (736).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (655).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (493).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (817).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (88).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (763).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (682).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (844).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (286).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (448).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (367).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (529).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (169).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (646).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (808).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (484).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (727).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (565).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (781).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (466).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (628).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (547).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (385).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (709).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (268).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (187).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (349).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (826).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (664).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (583).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (745).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (237).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (156).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (318).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (471).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (633).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (552).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (714).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (39).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (390).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (435).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (273).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (192).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (516).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (354).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (831).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (750).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (75).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (255).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (417).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (336).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (174).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (651).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (813).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (57).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (732).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (570).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (615).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (291).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (453).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (372).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (534).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (138).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (93).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (219).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (327).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (165).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (408).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (246).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (48).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (723).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (561).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (804).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (480).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (642).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (363).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (525).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (444).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (606).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (282).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (84).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (840).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (129).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (507).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (183).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (345).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (264).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (426).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (741).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (66).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (660).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (822).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (543).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (381).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (705).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (624).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (462).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (228).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (309).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (147).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (398).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (40).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (479).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (400).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (794).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (4).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (596).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (202).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (758).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (677).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (839).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (121).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (578).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (103).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (497).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (659).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (776).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (220).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (857).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (695).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (301).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (299).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (22).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (488).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (569).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (130).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (848).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (686).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (211).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (767).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (13).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (668).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (112).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (749).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (587).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (310).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (785).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (31).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (389).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (811).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (730).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (55).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (334).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (172).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (415).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (253).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (136).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (91).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (217).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (370).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (19).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (532).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (451).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (613).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (118).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (73).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (514).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (190).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (352).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (271).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (433).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (154).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (316).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (235).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (550).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (37).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (712).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (631).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (64).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (820).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (109).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (262).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (424).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (343).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (505).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (181).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (226).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (307).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (145).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (622).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (460).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (703).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (28).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (541).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (82).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (208).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (127).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (442).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (280).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (604).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (523).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (361).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (406).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (244).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (163).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (325).jpg
#   inflating: data/Normal Person ECG Images (859)/Normal (802).jpg
# ...
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (55).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (127).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI  (2).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (101).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI  (11).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (198).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (200).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (189).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (110).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI  (20).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (99).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (176).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (68).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (194).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (86).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (158).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (185).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (149).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (77).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (59).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (167).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (95).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (105).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI  (33).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (141).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI  (6).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (123).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (51).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI  (15).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (114).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI  (42).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (150).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (60).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (132).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI  (24).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (192).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI  (48).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (84).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (156).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (66).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (138).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (174).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (129).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (57).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (165).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (93).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (147).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (75).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI  (39).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (183).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (202).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (121).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI  (13).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI  (4).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (103).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI  (31).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (130).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI  (22).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (112).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI  (40).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (88).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (196).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (178).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (97).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (169).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (187).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (79).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (161).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI  (17).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (125).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (53).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI  (35).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (107).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (143).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (71).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI  (8).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (170).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI  (26).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (62).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (134).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI  (44).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (116).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (80).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (152).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (164).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (92).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (56).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (128).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI  (38).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (182).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (74).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (146).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI  (29).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (173).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (137).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (65).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (191).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI  (47).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (119).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (155).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (83).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI  (21).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (111).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (102).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI  (30).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI  (3).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (201).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (120).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (199).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI  (12).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (96).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (168).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (78).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (186).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (69).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (177).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (159).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (87).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (195).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (61).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (133).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI  (25).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (151).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (115).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI  (43).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (142).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI  (7).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (70).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (106).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI  (34).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (160).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI  (16).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (124).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (52).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (148).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (76).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (184).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (166).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (94).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (58).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (85).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (157).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (49).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (193).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (175).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (67).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (139).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI  (41).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (113).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI  (23).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (131).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI  (14).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (50).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (203).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (122).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI  (32).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (104).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI  (5).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (140).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (188).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (98).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (197).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI  (10).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (89).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI  (1).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (100).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (179).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (117).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI  (45).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (153).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (81).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (135).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (63).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (171).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI  (27).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (54).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (126).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (90).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI  (18).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (162).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (72).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI  (9).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (144).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI  (36).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (180).jpg
#   inflating: data/ECG Images of Patient that have History of MI (203)/PMI (108).jpg

# %%
data_transforms = transforms.Compose([
    transforms.Resize((1000,1000)),
    transforms.ToTensor()
    ])

# %%
data = ImageFolder('data/',transform=data_transforms)

# %%
test_size = 0.2
print(len(data))
num_train = len(data)
indices = list(range(num_train))
np.random.shuffle(indices)
test_split = int(np.floor((test_size) * num_train))
test_idx, train_idx = indices[:test_split], indices[test_split:]

print(len(test_idx), len(train_idx))

# define samplers for obtaining training and validation batches
train_sampler = SubsetRandomSampler(train_idx)
test_sampler = SubsetRandomSampler(test_idx)


loaders = {
    'train': torch.utils.data.DataLoader(data, batch_size=10, sampler=train_sampler),
    'test': torch.utils.data.DataLoader(data, batch_size=10, sampler=test_sampler)
}
# Out:
# 1109
# 221 888

# %%
vgg16 = torchvision.models.vgg16(pretrained=True)
for param in vgg16.features.parameters():
    param.requires_grad = False
num_ftrs = vgg16.classifier[6].in_features
vgg16.classifier[6] = nn.Linear(num_ftrs, 2)
vgg16 = vgg16.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(vgg16.parameters(), lr=0.001)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# HBox(children=(FloatProgress(value=0.0, max=553433881.0), HTML(value='')))

# %%
def Graphing(train,test):
    plt.plot(train)
    plt.plot(test)
    plt.legend(['Train Loss','Validation Loss'])

# %%
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True
from tqdm.notebook import tqdm

def train(n_epochs, loaders, model, optimizer, criterion, train_on_gpu, save_path):
    """returns trained model"""
    # initialize tracker for minimum validation loss
    valid_loss_min = np.Inf 
    train = []
    test = []
    accuracy = []
    correct,total = 0,0
    
    for epoch in tqdm(range(1, n_epochs+1)):
        # initialize variables to monitor training and validation loss
        train_loss = 0.0
        valid_loss = 0.0
        valid_min = 9999
        ###################
        # train the model #
        ###################
        model.train()
        for batch_idx, (input, target) in enumerate(loaders['train']):
            # move to GPU
            if train_on_gpu:
                input, target = input.cuda(), target.cuda()
            ## find the loss and update the model parameters accordingly
            ## record the average training loss, using something like
            ## train_loss = train_loss + ((1 / (batch_idx + 1)) * (loss.data - train_loss))
            optimizer.zero_grad()
            out = model(input)
            loss = criterion(out,target)
            loss.backward()
            optimizer.step()
            train_loss = train_loss + ((1 / (batch_idx + 1)) * (loss.data - train_loss))
            if batch_idx%20==0:
                print('Batch: {}\tEpoch: {} \tTraining Loss: {:.6f}'.format(
                batch_idx,
                epoch, 
                train_loss
                ))



        ######################    
        # validate the model #
        ######################
        model.eval()
        correct, total = 0, 0
        for batch_idx, (input, target) in enumerate(loaders['test']):
            # move to GPU
            if train_on_gpu:
                input, target = input.cuda(), target.cuda()
            output = model(input)
            loss = criterion(output,target)
            valid_loss = valid_loss + ((1 / (batch_idx + 1)) * (loss.data - valid_loss))
            _, predicted = torch.max(output.data, 1)
            total += target.size(0)
            correct += (predicted == target).sum().item()

            ## update the average validation loss

            
        train.append(train_loss)
        test.append (valid_loss)
        accuracy.append(correct/total)
        # print training/validation statistics 
        print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f} \tAccuracy: {:.6f}'.format(
            epoch, 
            train_loss,
            valid_loss,
            correct/total
            ))
        if valid_loss <= valid_loss_min:
            print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
            valid_loss_min,
            valid_loss))
            torch.save(model.state_dict(), save_path)
            valid_loss_min = valid_loss
        
        
    print(f"FOLD ACCURACY : {correct/total}")
    # return trained model
    # Graphing(train,test)
    return model


# # train the model
# train(3, loaders, vgg16, optimizer, criterion, train_on_gpu, 'model.pt')

# # load the model that got the best validation accuracy
# vgg16.load_state_dict(torch.load('model.pt'))

# %%
# model = torchvision.models.resnet50(pretrained=True)
# num_ftrs =  model.fc.in_features
# model.fc = nn.Linear(num_ftrs, 2)
# print(model)

# %%
splits = 10

kfold = KFold(n_splits=splits,shuffle=False)
for fold,(train_idx,test_idx) in enumerate(kfold.split(data)):
    print(f'FOLD {fold}')
    print('--------------------------------')


    train_sampler = SubsetRandomSampler(train_idx)
    test_sampler = SubsetRandomSampler(test_idx)
    loaders = {
    'train': torch.utils.data.DataLoader(data, batch_size=16, sampler=train_sampler),
    'test': torch.utils.data.DataLoader(data, batch_size=16, sampler=test_sampler)
    }
    vgg16 = torchvision.models.vgg16(pretrained=True)
    for param in vgg16.features.parameters():
        param.requires_grad = False
    num_ftrs = vgg16.classifier[6].in_features
    vgg16.classifier[6] = nn.Linear(num_ftrs, 2)
    model = vgg16.to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    train(3, loaders,   model, optimizer, criterion, train_on_gpu, 'model.pt')
    model.load_state_dict(torch.load('model.pt'))
# Out:
# FOLD 0
# --------------------------------
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Batch: 0	Epoch: 1 	Training Loss: 0.612855
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-11-e62e5765308c> in <module>()
#      21     criterion = nn.CrossEntropyLoss()
#      22     optimizer = optim.Adam(model.parameters(), lr=0.001)
# ---> 23     train(3, loaders,   model, optimizer, criterion, train_on_gpu, 'model.pt')
#      24     model.load_state_dict(torch.load('model.pt'))
#
# <ipython-input-8-15728210a9f6> in train(n_epochs, loaders, model, optimizer, criterion, train_on_gpu, save_path)
#      29             ## train_loss = train_loss + ((1 / (batch_idx + 1)) * (loss.data - train_loss))
#      30             optimizer.zero_grad()
# ---> 31             out = model(input)
#      32             loss = criterion(out,target)
#      33             loss.backward()
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/torchvision/models/vgg.py in forward(self, x)
#      47
#      48     def forward(self, x: torch.Tensor) -> torch.Tensor:
# ---> 49         x = self.features(x)
#      50         x = self.avgpool(x)
#      51         x = torch.flatten(x, 1)
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     137     def forward(self, input):
#     138         for module in self:
# --> 139             input = module(input)
#     140         return input
#     141
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/conv.py in forward(self, input)
#     441
#     442     def forward(self, input: Tensor) -> Tensor:
# --> 443         return self._conv_forward(input, self.weight, self.bias)
#     444
#     445 class Conv3d(_ConvNd):
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     438                             _pair(0), self.dilation, self.groups)
#     439         return F.conv2d(input, weight, bias, self.stride,
# --> 440                         self.padding, self.dilation, self.groups)
#     441
#     442     def forward(self, input: Tensor) -> Tensor:
#
# RuntimeError: CUDA out of memory. Tried to allocate 3.82 GiB (GPU 0; 14.76 GiB total capacity; 5.83 GiB already allocated; 2.52 GiB free; 11.17 GiB reserved in total by PyTorch)

# %%
# import json
# a_file = open("data.json", "w")
# json.dump(results, a_file)
# a_file.close()

# %%
# nSamples = [887, 6130, 480, 317, 972, 101, 128] #of class instances
# normedWeights = [1 - (x / sum(nSamples)) for x in nSamples]
# normedWeights = torch.FloatTensor(normedWeights).to(device)
# Criterion = nn.CrossEntropyLoss(weight=normedWeights)

# %%
# batch_size = 20
# class_sample_count = [10, 1, 20, 3, 4] # dataset has 10 class-1 samples, 1 class-2 samples, etc.
# weights = 1 / torch.Tensor(class_sample_count)
# sampler = torch.utils.data.sampler.WeightedRandomSampler(weights, batch_size)
# trainloader = data_utils.DataLoader(train_dataset, batch_size = batch_size, shuffle=True, sampler = sampler)
