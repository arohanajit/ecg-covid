# %% [markdown]
# <a href="https://colab.research.google.com/github/arohanajit/ecg-covid/blob/main/Untitled14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as Fl
from torchsummary import summary
from torch import optim
from torch.utils.data import DataLoader, TensorDataset, random_split
from torch.utils.data.sampler import SubsetRandomSampler
from torchvision.datasets import ImageFolder
import torchvision.transforms as transforms
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score
from tqdm import tqdm_notebook
import torchvision
import shutil
train_on_gpu = torch.cuda.is_available()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(train_on_gpu)
# Out:
# False

# %%
# from google.colab import drive
# drive.mount('content/')
# Out:
# Mounted at content/

# %%
# %%capture
# !mkdir data
# !unzip content/MyDrive/datasets/ecg.zip -d data/
# shutil.rmtree("data/ECG Images of Myocardial Infarction Patients (77)")
# shutil.rmtree("data/ECG Images of Patient that have abnormal heart beats (548)")
# shutil.rmtree("data/ECG Images of Patient that have History of MI (203)")

# %%
data_transforms = transforms.Compose([
    transforms.Resize((1000,1000)),
    transforms.ToTensor()
    ])

# %%
data = ImageFolder('data/',transform=data_transforms)

# %%
test_size = 0.2
print(len(data))
num_train = len(data)
indices = list(range(num_train))
np.random.shuffle(indices)
test_split = int(np.floor((test_size) * num_train))
test_idx, train_idx = indices[:test_split], indices[test_split:]

print(len(test_idx), len(train_idx))

# define samplers for obtaining training and validation batches
train_sampler = SubsetRandomSampler(train_idx)
test_sampler = SubsetRandomSampler(test_idx)


loaders = {
    'train': torch.utils.data.DataLoader(data, batch_size=10, sampler=train_sampler),
    'test': torch.utils.data.DataLoader(data, batch_size=10, sampler=test_sampler)
}
# Out:
# 1109
# 221 888

# %%
# vgg16 = torchvision.models.vgg16(pretrained=True)
# for param in vgg16.features.parameters():
#     param.requires_grad = False
# num_ftrs = vgg16.classifier[6].in_features
# vgg16.classifier[6] = nn.Linear(num_ftrs, 2)
# vgg16 = vgg16.to(device)
# criterion = nn.CrossEntropyLoss()
# optimizer = optim.Adam(vgg16.parameters(), lr=0.001)

# %%
def Graphing(train,test):
    plt.plot(train)
    plt.plot(test)
    plt.legend(['Train Loss','Validation Loss'])

# %%
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True
from tqdm.notebook import tqdm

def train(n_epochs, loaders, model, optimizer, criterion, train_on_gpu, save_path):
    """returns trained model"""
    # initialize tracker for minimum validation loss
    valid_loss_min = np.Inf 
    train = []
    test = []
    accuracy = []
    correct,total = 0,0
    
    for epoch in tqdm(range(1, n_epochs+1)):
        # initialize variables to monitor training and validation loss
        train_loss = 0.0
        valid_loss = 0.0
        valid_min = 9999
        ###################
        # train the model #
        ###################
        model.train()
        for batch_idx, (input, target) in enumerate(loaders['train']):
            # move to GPU
            if train_on_gpu:
                input, target = input.cuda(), target.cuda()
            ## find the loss and update the model parameters accordingly
            ## record the average training loss, using something like
            ## train_loss = train_loss + ((1 / (batch_idx + 1)) * (loss.data - train_loss))
            optimizer.zero_grad()
            out = model(input)
            loss = criterion(out,target)
            loss.backward()
            optimizer.step()
            train_loss = train_loss + ((1 / (batch_idx + 1)) * (loss.data - train_loss))
            if batch_idx%20==0:
                print('Batch: {}\tEpoch: {} \tTraining Loss: {:.6f}'.format(
                batch_idx,
                epoch, 
                train_loss
                ))



        ######################    
        # validate the model #
        ######################
        model.eval()
        correct, total = 0, 0
        for batch_idx, (input, target) in enumerate(loaders['test']):
            # move to GPU
            if train_on_gpu:
                input, target = input.cuda(), target.cuda()
            output = model(input)
            loss = criterion(output,target)
            valid_loss = valid_loss + ((1 / (batch_idx + 1)) * (loss.data - valid_loss))
            _, predicted = torch.max(output.data, 1)
            total += target.size(0)
            correct += (predicted == target).sum().item()

            ## update the average validation loss

            
        train.append(train_loss)
        test.append (valid_loss)
        accuracy.append(correct/total)
        # print training/validation statistics 
        print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f} \tAccuracy: {:.6f}'.format(
            epoch, 
            train_loss,
            valid_loss,
            correct/total
            ))
        if valid_loss <= valid_loss_min:
            print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
            valid_loss_min,
            valid_loss))
            torch.save(model.state_dict(), save_path)
            valid_loss_min = valid_loss
        
        
    print(f"FOLD ACCURACY : {correct/total}")
    # return trained model
    # Graphing(train,test)
    return model,train,test,accuracy


# # train the model
# train(3, loaders, vgg16, optimizer, criterion, train_on_gpu, 'model.pt')

# # load the model that got the best validation accuracy
# vgg16.load_state_dict(torch.load('model.pt'))

# %%
# model = torchvision.models.resnet18(pretrained=True)
# num_ftrs =  model.fc.in_features
# model.fc = nn.Linear(num_ftrs, 2)
# print(model)

# %%
results = {}

# %%
modelname = 'resnet18'
results[modelname] = {'fold':{}}
splits = [10]
for i in splits:
    results[modelname] = {'train':[],'test':[],'acc':[]}
    kfold = KFold(n_splits=i,shuffle=False)
    for fold,(train_idx,test_idx) in enumerate(kfold.split(data)):
        print(f'FOLD {fold}')
        print('--------------------------------')


        train_sampler = SubsetRandomSampler(train_idx)
        test_sampler = SubsetRandomSampler(test_idx)
        loaders = {
        'train': torch.utils.data.DataLoader(data, batch_size=16, sampler=train_sampler),
        'test': torch.utils.data.DataLoader(data, batch_size=16, sampler=test_sampler)
        }
        model = torchvision.models.resnet18(pretrained=True)
        for param in model.parameters():
            param.requires_grad = False
        num_ftrs =  model.fc.in_features
        model.fc = nn.Linear(num_ftrs, 2)
        model = model.to(device)
        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), lr=0.001)
        a,b,c,d = train(3, loaders,   model, optimizer, criterion, train_on_gpu, 'model.pt')
        results[modelname]['train'].append(round(b[-1].item(),2))
        results[modelname]['test'].append(round(c[-1].item(),2))
        results[modelname]['acc'].append(round(d[-1],2))
        model.load_state_dict(torch.load('model.pt'))
# Out:
# FOLD 0
# --------------------------------
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# HBox(children=(FloatProgress(value=0.0, max=46830571.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Batch: 0	Epoch: 1 	Training Loss: 0.349813
# Batch: 20	Epoch: 1 	Training Loss: 0.030930
# Batch: 40	Epoch: 1 	Training Loss: 0.015880
# Epoch: 1 	Training Loss: 0.013859 	Validation Loss: 6.921680 	Accuracy: 0.324324
# Validation loss decreased (inf --> 6.921680).  Saving model ...
# Batch: 0	Epoch: 2 	Training Loss: 0.000047
# Batch: 20	Epoch: 2 	Training Loss: 0.000044
# Batch: 40	Epoch: 2 	Training Loss: 0.000043
# Epoch: 2 	Training Loss: 0.000042 	Validation Loss: 7.457119 	Accuracy: 0.324324
# Batch: 0	Epoch: 3 	Training Loss: 0.000040
# Batch: 20	Epoch: 3 	Training Loss: 0.000040
# Batch: 40	Epoch: 3 	Training Loss: 0.000040
# Epoch: 3 	Training Loss: 0.000039 	Validation Loss: 7.381000 	Accuracy: 0.324324
#
# FOLD ACCURACY : 0.32432432432432434
# FOLD 1
# --------------------------------
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# Batch: 0	Epoch: 1 	Training Loss: 0.634560
# Batch: 20	Epoch: 1 	Training Loss: 0.413406
# Batch: 40	Epoch: 1 	Training Loss: 0.301265
# Epoch: 1 	Training Loss: 0.278397 	Validation Loss: 0.118547 	Accuracy: 1.000000
# Validation loss decreased (inf --> 0.118547).  Saving model ...
# Batch: 0	Epoch: 2 	Training Loss: 0.075674
# Batch: 20	Epoch: 2 	Training Loss: 0.132250
# Batch: 40	Epoch: 2 	Training Loss: 0.130760
# Epoch: 2 	Training Loss: 0.137764 	Validation Loss: 0.070534 	Accuracy: 1.000000
# Validation loss decreased (0.118547 --> 0.070534).  Saving model ...
# Batch: 0	Epoch: 3 	Training Loss: 0.092689
# Batch: 20	Epoch: 3 	Training Loss: 0.162728
# Batch: 40	Epoch: 3 	Training Loss: 0.153867
# Epoch: 3 	Training Loss: 0.149461 	Validation Loss: 0.017846 	Accuracy: 1.000000
# Validation loss decreased (0.070534 --> 0.017846).  Saving model ...
#
# FOLD ACCURACY : 1.0
# FOLD 2
# --------------------------------
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# Batch: 0	Epoch: 1 	Training Loss: 0.941795
# Batch: 20	Epoch: 1 	Training Loss: 0.468581
# Batch: 40	Epoch: 1 	Training Loss: 0.338713
# Epoch: 1 	Training Loss: 0.324635 	Validation Loss: 0.309394 	Accuracy: 1.000000
# Validation loss decreased (inf --> 0.309394).  Saving model ...
# Batch: 0	Epoch: 2 	Training Loss: 0.150397
# Batch: 20	Epoch: 2 	Training Loss: 0.131343
# Batch: 40	Epoch: 2 	Training Loss: 0.134714
# Epoch: 2 	Training Loss: 0.133809 	Validation Loss: 0.029230 	Accuracy: 1.000000
# Validation loss decreased (0.309394 --> 0.029230).  Saving model ...
# Batch: 0	Epoch: 3 	Training Loss: 0.041862
# Batch: 20	Epoch: 3 	Training Loss: 0.104114
# Batch: 40	Epoch: 3 	Training Loss: 0.106795
# Epoch: 3 	Training Loss: 0.110348 	Validation Loss: 0.031626 	Accuracy: 1.000000
#
# FOLD ACCURACY : 1.0
# FOLD 0
# --------------------------------
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# Batch: 0	Epoch: 1 	Training Loss: 0.638866
# Batch: 20	Epoch: 1 	Training Loss: 0.058747
# Batch: 40	Epoch: 1 	Training Loss: 0.030146
# Epoch: 1 	Training Loss: 0.023784 	Validation Loss: 8.702530 	Accuracy: 0.100719
# Validation loss decreased (inf --> 8.702530).  Saving model ...
# Batch: 0	Epoch: 2 	Training Loss: 0.000064
# Batch: 20	Epoch: 2 	Training Loss: 0.000062
# Batch: 40	Epoch: 2 	Training Loss: 0.000061
# Epoch: 2 	Training Loss: 0.000060 	Validation Loss: 9.243081 	Accuracy: 0.100719
# Batch: 0	Epoch: 3 	Training Loss: 0.000060
# Batch: 20	Epoch: 3 	Training Loss: 0.000058
# Batch: 40	Epoch: 3 	Training Loss: 0.000057
# Epoch: 3 	Training Loss: 0.000057 	Validation Loss: 9.311239 	Accuracy: 0.100719
#
# FOLD ACCURACY : 0.10071942446043165
# FOLD 1
# --------------------------------
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# Batch: 0	Epoch: 1 	Training Loss: 0.885868
# Batch: 20	Epoch: 1 	Training Loss: 0.477959
# Batch: 40	Epoch: 1 	Training Loss: 0.354987
# Epoch: 1 	Training Loss: 0.300492 	Validation Loss: 0.045352 	Accuracy: 1.000000
# Validation loss decreased (inf --> 0.045352).  Saving model ...
# Batch: 0	Epoch: 2 	Training Loss: 0.330019
# Batch: 20	Epoch: 2 	Training Loss: 0.186107
# Batch: 40	Epoch: 2 	Training Loss: 0.137690
# Epoch: 2 	Training Loss: 0.125115 	Validation Loss: 0.044044 	Accuracy: 1.000000
# Validation loss decreased (0.045352 --> 0.044044).  Saving model ...
# Batch: 0	Epoch: 3 	Training Loss: 0.047433
# Batch: 20	Epoch: 3 	Training Loss: 0.093503
# Batch: 40	Epoch: 3 	Training Loss: 0.087576
# Epoch: 3 	Training Loss: 0.089689 	Validation Loss: 0.015610 	Accuracy: 1.000000
# Validation loss decreased (0.044044 --> 0.015610).  Saving model ...
#
# FOLD ACCURACY : 1.0
# FOLD 2
# --------------------------------
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# Batch: 0	Epoch: 1 	Training Loss: 0.657554
# Batch: 20	Epoch: 1 	Training Loss: 0.428777
# Batch: 40	Epoch: 1 	Training Loss: 0.327252
# Epoch: 1 	Training Loss: 0.298173 	Validation Loss: 0.089089 	Accuracy: 1.000000
# Validation loss decreased (inf --> 0.089089).  Saving model ...
# Batch: 0	Epoch: 2 	Training Loss: 0.142174
# Batch: 20	Epoch: 2 	Training Loss: 0.126288
# Batch: 40	Epoch: 2 	Training Loss: 0.123666
# Epoch: 2 	Training Loss: 0.124483 	Validation Loss: 0.020662 	Accuracy: 1.000000
# Validation loss decreased (0.089089 --> 0.020662).  Saving model ...
# Batch: 0	Epoch: 3 	Training Loss: 0.230535
# Batch: 20	Epoch: 3 	Training Loss: 0.095810
# Batch: 40	Epoch: 3 	Training Loss: 0.101177
# Epoch: 3 	Training Loss: 0.098577 	Validation Loss: 0.012496 	Accuracy: 1.000000
# Validation loss decreased (0.020662 --> 0.012496).  Saving model ...
#
# FOLD ACCURACY : 1.0
# FOLD 3
# --------------------------------
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# Batch: 0	Epoch: 1 	Training Loss: 0.881294
# Batch: 20	Epoch: 1 	Training Loss: 0.500900
# Batch: 40	Epoch: 1 	Training Loss: 0.365147
# Epoch: 1 	Training Loss: 0.324541 	Validation Loss: 0.215810 	Accuracy: 1.000000
# Validation loss decreased (inf --> 0.215810).  Saving model ...
# Batch: 0	Epoch: 2 	Training Loss: 0.087163
# Batch: 20	Epoch: 2 	Training Loss: 0.113129
# Batch: 40	Epoch: 2 	Training Loss: 0.119872
# Epoch: 2 	Training Loss: 0.119570 	Validation Loss: 0.028064 	Accuracy: 1.000000
# Validation loss decreased (0.215810 --> 0.028064).  Saving model ...
# Batch: 0	Epoch: 3 	Training Loss: 0.217502
# Batch: 20	Epoch: 3 	Training Loss: 0.093521
# Batch: 40	Epoch: 3 	Training Loss: 0.099757
# Epoch: 3 	Training Loss: 0.091474 	Validation Loss: 0.015329 	Accuracy: 1.000000
# Validation loss decreased (0.028064 --> 0.015329).  Saving model ...
#
# FOLD ACCURACY : 1.0
# FOLD 0
# --------------------------------
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# Batch: 0	Epoch: 1 	Training Loss: 0.335160
# Batch: 20	Epoch: 1 	Training Loss: 0.142735
# Batch: 40	Epoch: 1 	Training Loss: 0.129763
# Epoch: 1 	Training Loss: 0.129221 	Validation Loss: 1.926473 	Accuracy: 0.000000
# Validation loss decreased (inf --> 1.926473).  Saving model ...
# Batch: 0	Epoch: 2 	Training Loss: 0.009486
# Batch: 20	Epoch: 2 	Training Loss: 0.106774
# Batch: 40	Epoch: 2 	Training Loss: 0.082804
# Epoch: 2 	Training Loss: 0.082939 	Validation Loss: 0.543093 	Accuracy: 0.599099
# Validation loss decreased (1.926473 --> 0.543093).  Saving model ...
# Batch: 0	Epoch: 3 	Training Loss: 0.226312
# Batch: 20	Epoch: 3 	Training Loss: 0.076034
# Batch: 40	Epoch: 3 	Training Loss: 0.081858
# Epoch: 3 	Training Loss: 0.069647 	Validation Loss: 0.515821 	Accuracy: 0.599099
# Validation loss decreased (0.543093 --> 0.515821).  Saving model ...
#
# FOLD ACCURACY : 0.5990990990990991
# FOLD 1
# --------------------------------
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# Batch: 0	Epoch: 1 	Training Loss: 0.791998
# Batch: 20	Epoch: 1 	Training Loss: 0.394421
# Batch: 40	Epoch: 1 	Training Loss: 0.262055
# Epoch: 1 	Training Loss: 0.216292 	Validation Loss: 0.216942 	Accuracy: 0.945946
# Validation loss decreased (inf --> 0.216942).  Saving model ...
# Batch: 0	Epoch: 2 	Training Loss: 0.047433
# Batch: 20	Epoch: 2 	Training Loss: 0.080092
# Batch: 40	Epoch: 2 	Training Loss: 0.058551
# Epoch: 2 	Training Loss: 0.052977 	Validation Loss: 0.230110 	Accuracy: 0.945946
# Batch: 0	Epoch: 3 	Training Loss: 0.019203
# Batch: 20	Epoch: 3 	Training Loss: 0.044402
# Batch: 40	Epoch: 3 	Training Loss: 0.036773
# Epoch: 3 	Training Loss: 0.030707 	Validation Loss: 0.272109 	Accuracy: 0.945946
#
# FOLD ACCURACY : 0.9459459459459459
# FOLD 2
# --------------------------------
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# Batch: 0	Epoch: 1 	Training Loss: 1.099293
# Batch: 20	Epoch: 1 	Training Loss: 0.589730
# Batch: 40	Epoch: 1 	Training Loss: 0.408174
# Epoch: 1 	Training Loss: 0.338611 	Validation Loss: 0.049370 	Accuracy: 1.000000
# Validation loss decreased (inf --> 0.049370).  Saving model ...
# Batch: 0	Epoch: 2 	Training Loss: 0.141757
# Batch: 20	Epoch: 2 	Training Loss: 0.135229
# Batch: 40	Epoch: 2 	Training Loss: 0.124810
# Epoch: 2 	Training Loss: 0.116433 	Validation Loss: 0.027377 	Accuracy: 1.000000
# Validation loss decreased (0.049370 --> 0.027377).  Saving model ...
# Batch: 0	Epoch: 3 	Training Loss: 0.055963
# Batch: 20	Epoch: 3 	Training Loss: 0.083258
# Batch: 40	Epoch: 3 	Training Loss: 0.097074
# Epoch: 3 	Training Loss: 0.086485 	Validation Loss: 0.006515 	Accuracy: 1.000000
# Validation loss decreased (0.027377 --> 0.006515).  Saving model ...
#
# FOLD ACCURACY : 1.0
# FOLD 3
# --------------------------------
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# Batch: 0	Epoch: 1 	Training Loss: 0.670170
# Batch: 20	Epoch: 1 	Training Loss: 0.322028
# Batch: 40	Epoch: 1 	Training Loss: 0.243192
# Epoch: 1 	Training Loss: 0.200775 	Validation Loss: 0.053578 	Accuracy: 1.000000
# Validation loss decreased (inf --> 0.053578).  Saving model ...
# Batch: 0	Epoch: 2 	Training Loss: 0.269246
# Batch: 20	Epoch: 2 	Training Loss: 0.058166
# Batch: 40	Epoch: 2 	Training Loss: 0.082676
# Epoch: 2 	Training Loss: 0.080164 	Validation Loss: 0.014417 	Accuracy: 1.000000
# Validation loss decreased (0.053578 --> 0.014417).  Saving model ...
# Batch: 0	Epoch: 3 	Training Loss: 0.030429
# Batch: 20	Epoch: 3 	Training Loss: 0.103736
# Batch: 40	Epoch: 3 	Training Loss: 0.100217
# Epoch: 3 	Training Loss: 0.093796 	Validation Loss: 0.005855 	Accuracy: 1.000000
# Validation loss decreased (0.014417 --> 0.005855).  Saving model ...
#
# FOLD ACCURACY : 1.0
# FOLD 4
# --------------------------------
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# Batch: 0	Epoch: 1 	Training Loss: 0.920450
# Batch: 20	Epoch: 1 	Training Loss: 0.455474
# Batch: 40	Epoch: 1 	Training Loss: 0.335467
# Epoch: 1 	Training Loss: 0.280239 	Validation Loss: 0.113810 	Accuracy: 1.000000
# Validation loss decreased (inf --> 0.113810).  Saving model ...
# Batch: 0	Epoch: 2 	Training Loss: 0.072126
# Batch: 20	Epoch: 2 	Training Loss: 0.114175
# Batch: 40	Epoch: 2 	Training Loss: 0.105723
# Epoch: 2 	Training Loss: 0.099480 	Validation Loss: 0.015940 	Accuracy: 1.000000
# Validation loss decreased (0.113810 --> 0.015940).  Saving model ...
# Batch: 0	Epoch: 3 	Training Loss: 0.035605
# Batch: 20	Epoch: 3 	Training Loss: 0.083936
# Batch: 40	Epoch: 3 	Training Loss: 0.093805
# Epoch: 3 	Training Loss: 0.104049 	Validation Loss: 0.021240 	Accuracy: 1.000000
#
# FOLD ACCURACY : 1.0
# FOLD 0
# --------------------------------
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# Batch: 0	Epoch: 1 	Training Loss: 0.558461
# Batch: 20	Epoch: 1 	Training Loss: 0.315745
# Batch: 40	Epoch: 1 	Training Loss: 0.229591
# Batch: 60	Epoch: 1 	Training Loss: 0.180089
# Epoch: 1 	Training Loss: 0.179268 	Validation Loss: 0.242082 	Accuracy: 1.000000
# Validation loss decreased (inf --> 0.242082).  Saving model ...
# Batch: 0	Epoch: 2 	Training Loss: 0.243179
# Batch: 20	Epoch: 2 	Training Loss: 0.092675
# Batch: 40	Epoch: 2 	Training Loss: 0.078029
# Batch: 60	Epoch: 2 	Training Loss: 0.074422
# Epoch: 2 	Training Loss: 0.073232 	Validation Loss: 0.207550 	Accuracy: 1.000000
# Validation loss decreased (0.242082 --> 0.207550).  Saving model ...
# Batch: 0	Epoch: 3 	Training Loss: 0.014536
# Batch: 20	Epoch: 3 	Training Loss: 0.085653
# Batch: 40	Epoch: 3 	Training Loss: 0.080422
# Batch: 60	Epoch: 3 	Training Loss: 0.066294
# Epoch: 3 	Training Loss: 0.065423 	Validation Loss: 0.091266 	Accuracy: 1.000000
# Validation loss decreased (0.207550 --> 0.091266).  Saving model ...
#
# FOLD ACCURACY : 1.0
# FOLD 1
# --------------------------------
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# Batch: 0	Epoch: 1 	Training Loss: 0.626294
# Batch: 20	Epoch: 1 	Training Loss: 0.334759
# Batch: 40	Epoch: 1 	Training Loss: 0.241732
# Batch: 60	Epoch: 1 	Training Loss: 0.198505
# Epoch: 1 	Training Loss: 0.198415 	Validation Loss: 0.156453 	Accuracy: 1.000000
# Validation loss decreased (inf --> 0.156453).  Saving model ...
# Batch: 0	Epoch: 2 	Training Loss: 0.058000
# Batch: 20	Epoch: 2 	Training Loss: 0.052932
# Batch: 40	Epoch: 2 	Training Loss: 0.064945
# Batch: 60	Epoch: 2 	Training Loss: 0.080949
# Epoch: 2 	Training Loss: 0.080032 	Validation Loss: 0.027464 	Accuracy: 1.000000
# Validation loss decreased (0.156453 --> 0.027464).  Saving model ...
# Batch: 0	Epoch: 3 	Training Loss: 0.203302
# Batch: 20	Epoch: 3 	Training Loss: 0.077544
# Batch: 40	Epoch: 3 	Training Loss: 0.073540
# Batch: 60	Epoch: 3 	Training Loss: 0.065109
# Epoch: 3 	Training Loss: 0.063682 	Validation Loss: 0.036800 	Accuracy: 1.000000
#
# FOLD ACCURACY : 1.0
# FOLD 2
# --------------------------------
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# Batch: 0	Epoch: 1 	Training Loss: 0.582062
# Batch: 20	Epoch: 1 	Training Loss: 0.350176
# Batch: 40	Epoch: 1 	Training Loss: 0.235800
# Batch: 60	Epoch: 1 	Training Loss: 0.180385
# Epoch: 1 	Training Loss: 0.175662 	Validation Loss: 0.435124 	Accuracy: 0.891892
# Validation loss decreased (inf --> 0.435124).  Saving model ...
# Batch: 0	Epoch: 2 	Training Loss: 0.031880
# Batch: 20	Epoch: 2 	Training Loss: 0.045800
# Batch: 40	Epoch: 2 	Training Loss: 0.044980
# Batch: 60	Epoch: 2 	Training Loss: 0.042847
# Epoch: 2 	Training Loss: 0.043900 	Validation Loss: 0.449518 	Accuracy: 0.891892
# Batch: 0	Epoch: 3 	Training Loss: 0.014150
# Batch: 20	Epoch: 3 	Training Loss: 0.020715
# Batch: 40	Epoch: 3 	Training Loss: 0.020612
# Batch: 60	Epoch: 3 	Training Loss: 0.020628
# Epoch: 3 	Training Loss: 0.020580 	Validation Loss: 0.628434 	Accuracy: 0.891892
#
# FOLD ACCURACY : 0.8918918918918919
# FOLD 3
# --------------------------------
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# Batch: 0	Epoch: 1 	Training Loss: 0.558944
# Batch: 20	Epoch: 1 	Training Loss: 0.334126
# Batch: 40	Epoch: 1 	Training Loss: 0.225502
# Batch: 60	Epoch: 1 	Training Loss: 0.186627
# Epoch: 1 	Training Loss: 0.182943 	Validation Loss: 0.058359 	Accuracy: 1.000000
# Validation loss decreased (inf --> 0.058359).  Saving model ...
# Batch: 0	Epoch: 2 	Training Loss: 0.080458
# Batch: 20	Epoch: 2 	Training Loss: 0.070469
# Batch: 40	Epoch: 2 	Training Loss: 0.087929
# Batch: 60	Epoch: 2 	Training Loss: 0.079480
# Epoch: 2 	Training Loss: 0.077582 	Validation Loss: 0.028277 	Accuracy: 1.000000
# Validation loss decreased (0.058359 --> 0.028277).  Saving model ...
# Batch: 0	Epoch: 3 	Training Loss: 0.021837
# Batch: 20	Epoch: 3 	Training Loss: 0.048095
# Batch: 40	Epoch: 3 	Training Loss: 0.075567
# Batch: 60	Epoch: 3 	Training Loss: 0.079588
# Epoch: 3 	Training Loss: 0.079312 	Validation Loss: 0.016785 	Accuracy: 1.000000
# Validation loss decreased (0.028277 --> 0.016785).  Saving model ...
#
# FOLD ACCURACY : 1.0
# FOLD 4
# --------------------------------
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# Batch: 0	Epoch: 1 	Training Loss: 0.803318
# Batch: 20	Epoch: 1 	Training Loss: 0.455120
# Batch: 40	Epoch: 1 	Training Loss: 0.339194
# Batch: 60	Epoch: 1 	Training Loss: 0.268788
# Epoch: 1 	Training Loss: 0.265083 	Validation Loss: 0.031768 	Accuracy: 1.000000
# Validation loss decreased (inf --> 0.031768).  Saving model ...
# Batch: 0	Epoch: 2 	Training Loss: 0.054781
# Batch: 20	Epoch: 2 	Training Loss: 0.109337
# Batch: 40	Epoch: 2 	Training Loss: 0.114456
# Batch: 60	Epoch: 2 	Training Loss: 0.099011
# Epoch: 2 	Training Loss: 0.105641 	Validation Loss: 0.010015 	Accuracy: 1.000000
# Validation loss decreased (0.031768 --> 0.010015).  Saving model ...
# Batch: 0	Epoch: 3 	Training Loss: 0.033909
# Batch: 20	Epoch: 3 	Training Loss: 0.123833
# Batch: 40	Epoch: 3 	Training Loss: 0.108184
# Batch: 60	Epoch: 3 	Training Loss: 0.093087
# Epoch: 3 	Training Loss: 0.092779 	Validation Loss: 0.006249 	Accuracy: 1.000000
# Validation loss decreased (0.010015 --> 0.006249).  Saving model ...
#
# FOLD ACCURACY : 1.0
# FOLD 5
# --------------------------------
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# Batch: 0	Epoch: 1 	Training Loss: 0.626295
# Batch: 20	Epoch: 1 	Training Loss: 0.410159
# Batch: 40	Epoch: 1 	Training Loss: 0.283045
# Batch: 60	Epoch: 1 	Training Loss: 0.236393
# Epoch: 1 	Training Loss: 0.234270 	Validation Loss: 0.076538 	Accuracy: 1.000000
# Validation loss decreased (inf --> 0.076538).  Saving model ...
# Batch: 0	Epoch: 2 	Training Loss: 0.079219
# Batch: 20	Epoch: 2 	Training Loss: 0.106812
# Batch: 40	Epoch: 2 	Training Loss: 0.080280
# Batch: 60	Epoch: 2 	Training Loss: 0.083440
# Epoch: 2 	Training Loss: 0.082054 	Validation Loss: 0.020085 	Accuracy: 1.000000
# Validation loss decreased (0.076538 --> 0.020085).  Saving model ...
# Batch: 0	Epoch: 3 	Training Loss: 0.074481
# Batch: 20	Epoch: 3 	Training Loss: 0.098788
# Batch: 40	Epoch: 3 	Training Loss: 0.095586
# Batch: 60	Epoch: 3 	Training Loss: 0.091926
# Epoch: 3 	Training Loss: 0.089578 	Validation Loss: 0.008238 	Accuracy: 1.000000
# Validation loss decreased (0.020085 --> 0.008238).  Saving model ...
#
# FOLD ACCURACY : 1.0
# FOLD 6
# --------------------------------
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# Batch: 0	Epoch: 1 	Training Loss: 0.705302
# Batch: 20	Epoch: 1 	Training Loss: 0.355015
# Batch: 40	Epoch: 1 	Training Loss: 0.270530
# Batch: 60	Epoch: 1 	Training Loss: 0.222003
# Epoch: 1 	Training Loss: 0.217758 	Validation Loss: 0.037972 	Accuracy: 1.000000
# Validation loss decreased (inf --> 0.037972).  Saving model ...
# Batch: 0	Epoch: 2 	Training Loss: 0.072113
# Batch: 20	Epoch: 2 	Training Loss: 0.090368
# Batch: 40	Epoch: 2 	Training Loss: 0.084370
# Batch: 60	Epoch: 2 	Training Loss: 0.088798
# Epoch: 2 	Training Loss: 0.093896 	Validation Loss: 0.025239 	Accuracy: 1.000000
# Validation loss decreased (0.037972 --> 0.025239).  Saving model ...
# Batch: 0	Epoch: 3 	Training Loss: 0.036920
# Batch: 20	Epoch: 3 	Training Loss: 0.108177
# Batch: 40	Epoch: 3 	Training Loss: 0.092414
# Batch: 60	Epoch: 3 	Training Loss: 0.088565
# Epoch: 3 	Training Loss: 0.086632 	Validation Loss: 0.019121 	Accuracy: 1.000000
# Validation loss decreased (0.025239 --> 0.019121).  Saving model ...
#
# FOLD ACCURACY : 1.0
# FOLD 7
# --------------------------------
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# Batch: 0	Epoch: 1 	Training Loss: 1.103188
# Batch: 20	Epoch: 1 	Training Loss: 0.516492
# Batch: 40	Epoch: 1 	Training Loss: 0.380481
# Batch: 60	Epoch: 1 	Training Loss: 0.305044
# Epoch: 1 	Training Loss: 0.303010 	Validation Loss: 0.028210 	Accuracy: 1.000000
# Validation loss decreased (inf --> 0.028210).  Saving model ...
# Batch: 0	Epoch: 2 	Training Loss: 0.065058
# Batch: 20	Epoch: 2 	Training Loss: 0.130800
# Batch: 40	Epoch: 2 	Training Loss: 0.126576
# Batch: 60	Epoch: 2 	Training Loss: 0.107429
# Epoch: 2 	Training Loss: 0.105135 	Validation Loss: 0.015112 	Accuracy: 1.000000
# Validation loss decreased (0.028210 --> 0.015112).  Saving model ...
# Batch: 0	Epoch: 3 	Training Loss: 0.051466
# Batch: 20	Epoch: 3 	Training Loss: 0.077865
# Batch: 40	Epoch: 3 	Training Loss: 0.088552
# Batch: 60	Epoch: 3 	Training Loss: 0.092471
# Epoch: 3 	Training Loss: 0.090364 	Validation Loss: 0.010808 	Accuracy: 1.000000
# Validation loss decreased (0.015112 --> 0.010808).  Saving model ...
#
# FOLD ACCURACY : 1.0
# FOLD 8
# --------------------------------
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# Batch: 0	Epoch: 1 	Training Loss: 0.577390
# Batch: 20	Epoch: 1 	Training Loss: 0.334940
# Batch: 40	Epoch: 1 	Training Loss: 0.230128
# Batch: 60	Epoch: 1 	Training Loss: 0.193026
# Epoch: 1 	Training Loss: 0.187900 	Validation Loss: 0.023511 	Accuracy: 1.000000
# Validation loss decreased (inf --> 0.023511).  Saving model ...
# Batch: 0	Epoch: 2 	Training Loss: 0.081909
# Batch: 20	Epoch: 2 	Training Loss: 0.081605
# Batch: 40	Epoch: 2 	Training Loss: 0.085739
# Batch: 60	Epoch: 2 	Training Loss: 0.085917
# Epoch: 2 	Training Loss: 0.084499 	Validation Loss: 0.017257 	Accuracy: 1.000000
# Validation loss decreased (0.023511 --> 0.017257).  Saving model ...
# Batch: 0	Epoch: 3 	Training Loss: 0.028715
# Batch: 20	Epoch: 3 	Training Loss: 0.085774
# Batch: 40	Epoch: 3 	Training Loss: 0.084323
# Batch: 60	Epoch: 3 	Training Loss: 0.085186
# Epoch: 3 	Training Loss: 0.083989 	Validation Loss: 0.005423 	Accuracy: 1.000000
# Validation loss decreased (0.017257 --> 0.005423).  Saving model ...
#
# FOLD ACCURACY : 1.0
# FOLD 9
# --------------------------------
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# Batch: 0	Epoch: 1 	Training Loss: 1.322188
# Batch: 20	Epoch: 1 	Training Loss: 0.578416
# Batch: 40	Epoch: 1 	Training Loss: 0.415415
# Batch: 60	Epoch: 1 	Training Loss: 0.331221
# Epoch: 1 	Training Loss: 0.323229 	Validation Loss: 0.051976 	Accuracy: 1.000000
# Validation loss decreased (inf --> 0.051976).  Saving model ...
# Batch: 0	Epoch: 2 	Training Loss: 0.072225
# Batch: 20	Epoch: 2 	Training Loss: 0.142108
# Batch: 40	Epoch: 2 	Training Loss: 0.118692
# Batch: 60	Epoch: 2 	Training Loss: 0.127836
# Epoch: 2 	Training Loss: 0.132757 	Validation Loss: 0.050653 	Accuracy: 1.000000
# Validation loss decreased (0.051976 --> 0.050653).  Saving model ...
# Batch: 0	Epoch: 3 	Training Loss: 0.027854
# Batch: 20	Epoch: 3 	Training Loss: 0.067664
# Batch: 40	Epoch: 3 	Training Loss: 0.077827
# Batch: 60	Epoch: 3 	Training Loss: 0.076987
# Epoch: 3 	Training Loss: 0.077991 	Validation Loss: 0.017504 	Accuracy: 1.000000
# Validation loss decreased (0.050653 --> 0.017504).  Saving model ...
#
# FOLD ACCURACY : 1.0

# %%
# nSamples = [887, 6130, 480, 317, 972, 101, 128] #of class instances
# normedWeights = [1 - (x / sum(nSamples)) for x in nSamples]
# normedWeights = torch.FloatTensor(normedWeights).to(device)
# Criterion = nn.CrossEntropyLoss(weight=normedWeights)

# %%
# batch_size = 20
# class_sample_count = [10, 1, 20, 3, 4] # dataset has 10 class-1 samples, 1 class-2 samples, etc.
# weights = 1 / torch.Tensor(class_sample_count)
# sampler = torch.utils.data.sampler.WeightedRandomSampler(weights, batch_size)
# trainloader = data_utils.DataLoader(train_dataset, batch_size = batch_size, shuffle=True, sampler = sampler)
