# %% [markdown]
# <a href="https://colab.research.google.com/github/arohanajit/ecg-covid/blob/main/Untitled14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as Fl
from torchsummary import summary
from torch import optim
from torch.utils.data import DataLoader, TensorDataset, random_split
from torch.utils.data.sampler import SubsetRandomSampler
from torchvision.datasets import ImageFolder
import torchvision.transforms as transforms
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score
from tqdm import tqdm_notebook
import torchvision
import shutil
train_on_gpu = torch.cuda.is_available()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(train_on_gpu)
# Out:
# True

# %%
# %%capture
# !git clone https://arohanajit:TXhqMLvKoeiUtMy_Xtrz@gitlab.com/arohanajit/ecg-covid.git
# !unzip ecg-covid/data.zip
# shutil.rmtree("data/heart")
# shutil.rmtree("ecg-covid")

# %%
data_transforms = transforms.Compose([
    transforms.Resize((500,500)),
    transforms.ToTensor()
    ])

# %%
data = ImageFolder('data/',transform=data_transforms)

# %%
test_size = 0.2
print(len(data))
num_train = len(data)
indices = list(range(num_train))
np.random.shuffle(indices)
test_split = int(np.floor((test_size) * num_train))
test_idx, train_idx = indices[:test_split], indices[test_split:]

print(len(test_idx), len(train_idx))

# define samplers for obtaining training and validation batches
train_sampler = SubsetRandomSampler(train_idx)
test_sampler = SubsetRandomSampler(test_idx)


loaders = {
    'train': torch.utils.data.DataLoader(data, batch_size=10, sampler=train_sampler),
    'test': torch.utils.data.DataLoader(data, batch_size=10, sampler=test_sampler)
}
# Out:
# 1109
# 221 888

# %%
vgg16 = torchvision.models.vgg16(pretrained=True)
for param in vgg16.features.parameters():
    param.requires_grad = False
num_ftrs = vgg16.classifier[6].in_features
vgg16.classifier[6] = nn.Linear(num_ftrs, 2)
vgg16 = vgg16.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(vgg16.parameters(), lr=0.001)

# %%
def Graphing(train,test):
    plt.plot(train)
    plt.plot(test)
    plt.legend(['Train Loss','Validation Loss'])

# %%
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True
from tqdm.notebook import tqdm

def train(n_epochs, loaders, model, optimizer, criterion, train_on_gpu, save_path):
    """returns trained model"""
    # initialize tracker for minimum validation loss
    valid_loss_min = np.Inf 
    train = []
    test = []
    accuracy = []
    correct,total = 0,0
    
    for epoch in tqdm(range(1, n_epochs+1)):
        # initialize variables to monitor training and validation loss
        train_loss = 0.0
        valid_loss = 0.0
        valid_min = 9999
        ###################
        # train the model #
        ###################
        model.train()
        for batch_idx, (input, target) in enumerate(loaders['train']):
            # move to GPU
            if train_on_gpu:
                input, target = input.cuda(), target.cuda()
            ## find the loss and update the model parameters accordingly
            ## record the average training loss, using something like
            ## train_loss = train_loss + ((1 / (batch_idx + 1)) * (loss.data - train_loss))
            optimizer.zero_grad()
            out = model(input)
            loss = criterion(out,target)
            loss.backward()
            optimizer.step()
            train_loss = train_loss + ((1 / (batch_idx + 1)) * (loss.data - train_loss))
            if batch_idx%20==0:
                print('Batch: {}\tEpoch: {} \tTraining Loss: {:.6f}'.format(
                batch_idx,
                epoch, 
                train_loss
                ))



        ######################    
        # validate the model #
        ######################
        model.eval()
        correct, total = 0, 0
        for batch_idx, (input, target) in enumerate(loaders['test']):
            # move to GPU
            if train_on_gpu:
                input, target = input.cuda(), target.cuda()
            output = model(input)
            loss = criterion(output,target)
            valid_loss = valid_loss + ((1 / (batch_idx + 1)) * (loss.data - valid_loss))
            _, predicted = torch.max(output.data, 1)
            total += target.size(0)
            correct += (predicted == target).sum().item()

            ## update the average validation loss

            
        train.append(train_loss)
        test.append (valid_loss)
        accuracy.append(correct/total)
        # print training/validation statistics 
        print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f} \tAccuracy: {:.6f}'.format(
            epoch, 
            train_loss,
            valid_loss,
            correct/total
            ))
        if valid_loss <= valid_loss_min:
            print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
            valid_loss_min,
            valid_loss))
            torch.save(model.state_dict(), save_path)
            valid_loss_min = valid_loss
        
        
    print(f"FOLD ACCURACY : {correct/total}")
    # return trained model
    # Graphing(train,test)
    return model


# # train the model
# train(3, loaders, vgg16, optimizer, criterion, train_on_gpu, 'model.pt')

# # load the model that got the best validation accuracy
# vgg16.load_state_dict(torch.load('model.pt'))

# %%
# model = torchvision.models.resnet50(pretrained=True)
# num_ftrs =  model.fc.in_features
# model.fc = nn.Linear(num_ftrs, 2)
# print(model)

# %%
splits = 10

kfold = KFold(n_splits=splits,shuffle=False)
for fold,(train_idx,test_idx) in enumerate(kfold.split(data)):
    print(f'FOLD {fold}')
    print('--------------------------------')


    train_sampler = SubsetRandomSampler(train_idx)
    test_sampler = SubsetRandomSampler(test_idx)
    loaders = {
    'train': torch.utils.data.DataLoader(data, batch_size=16, sampler=train_sampler),
    'test': torch.utils.data.DataLoader(data, batch_size=16, sampler=test_sampler)
    }
    vgg16 = torchvision.models.vgg16(pretrained=True)
    for param in vgg16.features.parameters():
        param.requires_grad = False
    num_ftrs = vgg16.classifier[6].in_features
    vgg16.classifier[6] = nn.Linear(num_ftrs, 2)
    model = vgg16.to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    train(3, loaders,   model, optimizer, criterion, train_on_gpu, 'model.pt')
    model.load_state_dict(torch.load('model.pt'))
# Out:
# FOLD 0
# --------------------------------
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Batch: 0	Epoch: 1 	Training Loss: 0.706155
# Batch: 20	Epoch: 1 	Training Loss: 0.404859
# Batch: 40	Epoch: 1 	Training Loss: 0.489249
# Batch: 60	Epoch: 1 	Training Loss: 0.481307
# Epoch: 1 	Training Loss: 0.481851 	Validation Loss: 0.000000 	Accuracy: 1.000000
# Validation loss decreased (inf --> 0.000000).  Saving model ...
# Batch: 0	Epoch: 2 	Training Loss: 0.000000
# Batch: 20	Epoch: 2 	Training Loss: 0.390217
# Batch: 40	Epoch: 2 	Training Loss: 0.324671
# Batch: 60	Epoch: 2 	Training Loss: 0.256693
# Epoch: 2 	Training Loss: 0.255575 	Validation Loss: 0.000000 	Accuracy: 1.000000
# Validation loss decreased (0.000000 --> 0.000000).  Saving model ...
# Batch: 0	Epoch: 3 	Training Loss: 0.000000
# Batch: 20	Epoch: 3 	Training Loss: 0.151698
# Batch: 40	Epoch: 3 	Training Loss: 0.230465
# Batch: 60	Epoch: 3 	Training Loss: 0.232964
# Epoch: 3 	Training Loss: 0.225569 	Validation Loss: 0.000000 	Accuracy: 1.000000
# Validation loss decreased (0.000000 --> 0.000000).  Saving model ...
#
# FOLD ACCURACY : 1.0
# FOLD 1
# --------------------------------
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# Batch: 0	Epoch: 1 	Training Loss: 0.733712
# Batch: 20	Epoch: 1 	Training Loss: 0.568700
# Batch: 40	Epoch: 1 	Training Loss: 0.482968
# Batch: 60	Epoch: 1 	Training Loss: 0.441614
# Epoch: 1 	Training Loss: 0.427598 	Validation Loss: 0.002939 	Accuracy: 1.000000
# Validation loss decreased (inf --> 0.002939).  Saving model ...
# Batch: 0	Epoch: 2 	Training Loss: 0.000000
# Batch: 20	Epoch: 2 	Training Loss: 0.112663
# Batch: 40	Epoch: 2 	Training Loss: 0.162606
# Batch: 60	Epoch: 2 	Training Loss: 0.223733
# Epoch: 2 	Training Loss: 0.222978 	Validation Loss: 0.000000 	Accuracy: 1.000000
# Validation loss decreased (0.002939 --> 0.000000).  Saving model ...
# Batch: 0	Epoch: 3 	Training Loss: 0.044795
# Batch: 20	Epoch: 3 	Training Loss: 0.293258
# Batch: 40	Epoch: 3 	Training Loss: 0.570494
# Batch: 60	Epoch: 3 	Training Loss: 0.533861
# Epoch: 3 	Training Loss: 0.516913 	Validation Loss: 0.000000 	Accuracy: 1.000000
# Validation loss decreased (0.000000 --> 0.000000).  Saving model ...
#
# FOLD ACCURACY : 1.0
# FOLD 2
# --------------------------------
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# Batch: 0	Epoch: 1 	Training Loss: 0.643230
# Batch: 20	Epoch: 1 	Training Loss: 0.480329
# Batch: 40	Epoch: 1 	Training Loss: 0.259323
# Batch: 60	Epoch: 1 	Training Loss: 0.174652
# Epoch: 1 	Training Loss: 0.169107 	Validation Loss: 5.286650 	Accuracy: 0.891892
# Validation loss decreased (inf --> 5.286650).  Saving model ...
# Batch: 0	Epoch: 2 	Training Loss: 0.000000
# Batch: 20	Epoch: 2 	Training Loss: 0.000013
# Batch: 40	Epoch: 2 	Training Loss: 0.000007
# Batch: 60	Epoch: 2 	Training Loss: 0.000005
# Epoch: 2 	Training Loss: 0.000005 	Validation Loss: 5.950883 	Accuracy: 0.891892
# Batch: 0	Epoch: 3 	Training Loss: 0.000000
# Batch: 20	Epoch: 3 	Training Loss: 0.000003
# Batch: 40	Epoch: 3 	Training Loss: 0.000001
# Batch: 60	Epoch: 3 	Training Loss: 0.000001
# Epoch: 3 	Training Loss: 0.000001 	Validation Loss: 5.045111 	Accuracy: 0.891892
# Validation loss decreased (5.286650 --> 5.045111).  Saving model ...
#
# FOLD ACCURACY : 0.8918918918918919
# FOLD 3
# --------------------------------
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# Batch: 0	Epoch: 1 	Training Loss: 0.610915
# Batch: 20	Epoch: 1 	Training Loss: 0.475259
# Batch: 40	Epoch: 1 	Training Loss: 0.402871
# Batch: 60	Epoch: 1 	Training Loss: 0.358680
# Epoch: 1 	Training Loss: 0.389381 	Validation Loss: 0.165582 	Accuracy: 0.909910
# Validation loss decreased (inf --> 0.165582).  Saving model ...
# Batch: 0	Epoch: 2 	Training Loss: 0.276623
# Batch: 20	Epoch: 2 	Training Loss: 0.355438
# Batch: 40	Epoch: 2 	Training Loss: 0.277776
# Batch: 60	Epoch: 2 	Training Loss: 0.262784
# Epoch: 2 	Training Loss: 0.254442 	Validation Loss: 0.000000 	Accuracy: 1.000000
# Validation loss decreased (0.165582 --> 0.000000).  Saving model ...
# Batch: 0	Epoch: 3 	Training Loss: 0.694438
# Batch: 20	Epoch: 3 	Training Loss: 0.228645
# Batch: 40	Epoch: 3 	Training Loss: 0.478280
# Batch: 60	Epoch: 3 	Training Loss: 0.367361
# Epoch: 3 	Training Loss: 0.355699 	Validation Loss: 0.000002 	Accuracy: 1.000000
#
# FOLD ACCURACY : 1.0
# FOLD 4
# --------------------------------
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# Batch: 0	Epoch: 1 	Training Loss: 0.746800
# Batch: 20	Epoch: 1 	Training Loss: 0.652288
# Batch: 40	Epoch: 1 	Training Loss: 0.536727
# Batch: 60	Epoch: 1 	Training Loss: 0.529764
# Epoch: 1 	Training Loss: 0.512946 	Validation Loss: 0.000000 	Accuracy: 1.000000
# Validation loss decreased (inf --> 0.000000).  Saving model ...
# Batch: 0	Epoch: 2 	Training Loss: 0.000011
# Batch: 20	Epoch: 2 	Training Loss: 0.297843
# Batch: 40	Epoch: 2 	Training Loss: 0.266222
# Batch: 60	Epoch: 2 	Training Loss: 0.261042
# Epoch: 2 	Training Loss: 0.252755 	Validation Loss: 0.000048 	Accuracy: 1.000000
# Batch: 0	Epoch: 3 	Training Loss: 0.459120
# Batch: 20	Epoch: 3 	Training Loss: 0.174784
# Batch: 40	Epoch: 3 	Training Loss: 0.195034
# Batch: 60	Epoch: 3 	Training Loss: 0.226036
# Epoch: 3 	Training Loss: 0.228478 	Validation Loss: 0.000000 	Accuracy: 1.000000
# Validation loss decreased (0.000000 --> 0.000000).  Saving model ...
#
# FOLD ACCURACY : 1.0
# FOLD 5
# --------------------------------
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# Batch: 0	Epoch: 1 	Training Loss: 0.762215
# Batch: 20	Epoch: 1 	Training Loss: 0.551451
# Batch: 40	Epoch: 1 	Training Loss: 0.370226
# Batch: 60	Epoch: 1 	Training Loss: 0.365040
# Epoch: 1 	Training Loss: 0.353604 	Validation Loss: 0.021807 	Accuracy: 1.000000
# Validation loss decreased (inf --> 0.021807).  Saving model ...
# Batch: 0	Epoch: 2 	Training Loss: 0.201543
# Batch: 20	Epoch: 2 	Training Loss: 0.132583
# Batch: 40	Epoch: 2 	Training Loss: 0.193098
# Batch: 60	Epoch: 2 	Training Loss: 0.215220
# Epoch: 2 	Training Loss: 0.233624 	Validation Loss: 0.000000 	Accuracy: 1.000000
# Validation loss decreased (0.021807 --> 0.000000).  Saving model ...
# Batch: 0	Epoch: 3 	Training Loss: 0.000000
# Batch: 20	Epoch: 3 	Training Loss: 0.245175
# Batch: 40	Epoch: 3 	Training Loss: 0.407618
# Batch: 60	Epoch: 3 	Training Loss: 0.333352
# Epoch: 3 	Training Loss: 0.322844 	Validation Loss: 0.161798 	Accuracy: 0.945946
#
# FOLD ACCURACY : 0.9459459459459459
# FOLD 6
# --------------------------------
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# Batch: 0	Epoch: 1 	Training Loss: 0.809020
# Batch: 20	Epoch: 1 	Training Loss: 0.626290
# Batch: 40	Epoch: 1 	Training Loss: 0.470123
# Batch: 60	Epoch: 1 	Training Loss: 0.368581
# Epoch: 1 	Training Loss: 0.356906 	Validation Loss: 0.000728 	Accuracy: 1.000000
# Validation loss decreased (inf --> 0.000728).  Saving model ...
# Batch: 0	Epoch: 2 	Training Loss: 0.039510
# Batch: 20	Epoch: 2 	Training Loss: 0.200553
# Batch: 40	Epoch: 2 	Training Loss: 0.204647
# Batch: 60	Epoch: 2 	Training Loss: 0.379764
# Epoch: 2 	Training Loss: 0.482470 	Validation Loss: 0.000000 	Accuracy: 1.000000
# Validation loss decreased (0.000728 --> 0.000000).  Saving model ...
# Batch: 0	Epoch: 3 	Training Loss: 0.000000
# Batch: 20	Epoch: 3 	Training Loss: 0.454118
# Batch: 40	Epoch: 3 	Training Loss: 0.382318
# Batch: 60	Epoch: 3 	Training Loss: 0.293954
# Epoch: 3 	Training Loss: 0.313557 	Validation Loss: 2.113975 	Accuracy: 0.783784
#
# FOLD ACCURACY : 0.7837837837837838
# FOLD 7
# --------------------------------
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# Batch: 0	Epoch: 1 	Training Loss: 0.740328
# Batch: 20	Epoch: 1 	Training Loss: 0.531211
# Batch: 40	Epoch: 1 	Training Loss: 0.508885
# Batch: 60	Epoch: 1 	Training Loss: 0.410476
# Epoch: 1 	Training Loss: 0.397464 	Validation Loss: 0.000000 	Accuracy: 1.000000
# Validation loss decreased (inf --> 0.000000).  Saving model ...
# Batch: 0	Epoch: 2 	Training Loss: 0.000001
# Batch: 20	Epoch: 2 	Training Loss: 0.204396
# Batch: 40	Epoch: 2 	Training Loss: 0.219444
# Batch: 60	Epoch: 2 	Training Loss: 0.391373
# Epoch: 2 	Training Loss: 0.378961 	Validation Loss: 0.000022 	Accuracy: 1.000000
# Batch: 0	Epoch: 3 	Training Loss: 0.476092
# Batch: 20	Epoch: 3 	Training Loss: 0.076833
# Batch: 40	Epoch: 3 	Training Loss: 0.166227
# Batch: 60	Epoch: 3 	Training Loss: 0.240817
# Epoch: 3 	Training Loss: 0.260439 	Validation Loss: 0.000000 	Accuracy: 1.000000
#
# FOLD ACCURACY : 1.0
# FOLD 8
# --------------------------------
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# Batch: 0	Epoch: 1 	Training Loss: 0.727956
# Batch: 20	Epoch: 1 	Training Loss: 0.399251
# Batch: 40	Epoch: 1 	Training Loss: 0.392385
# Batch: 60	Epoch: 1 	Training Loss: 0.416342
# Epoch: 1 	Training Loss: 0.403182 	Validation Loss: 0.000048 	Accuracy: 1.000000
# Validation loss decreased (inf --> 0.000048).  Saving model ...
# Batch: 0	Epoch: 2 	Training Loss: 0.001253
# Batch: 20	Epoch: 2 	Training Loss: 0.174241
# Batch: 40	Epoch: 2 	Training Loss: 0.366326
# Batch: 60	Epoch: 2 	Training Loss: 0.397261
# Epoch: 2 	Training Loss: 0.390831 	Validation Loss: 0.366598 	Accuracy: 0.891892
# Batch: 0	Epoch: 3 	Training Loss: 1.896936
# Batch: 20	Epoch: 3 	Training Loss: 0.425103
# Batch: 40	Epoch: 3 	Training Loss: 0.513217
# Batch: 60	Epoch: 3 	Training Loss: 0.430182
# Epoch: 3 	Training Loss: 0.416525 	Validation Loss: 0.000000 	Accuracy: 1.000000
# Validation loss decreased (0.000048 --> 0.000000).  Saving model ...
#
# FOLD ACCURACY : 1.0
# FOLD 9
# --------------------------------
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# Batch: 0	Epoch: 1 	Training Loss: 0.675005
# Batch: 20	Epoch: 1 	Training Loss: 0.667526
# Batch: 40	Epoch: 1 	Training Loss: 0.470060
# Batch: 60	Epoch: 1 	Training Loss: 0.351514
# Epoch: 1 	Training Loss: 0.341205 	Validation Loss: 0.000028 	Accuracy: 1.000000
# Validation loss decreased (inf --> 0.000028).  Saving model ...
# Batch: 0	Epoch: 2 	Training Loss: 0.000155
# Batch: 20	Epoch: 2 	Training Loss: 0.352660
# Batch: 40	Epoch: 2 	Training Loss: 0.252839
# Batch: 60	Epoch: 2 	Training Loss: 0.304286
# Epoch: 2 	Training Loss: 0.294909 	Validation Loss: 0.000067 	Accuracy: 1.000000
# Batch: 0	Epoch: 3 	Training Loss: 0.246670
# Batch: 20	Epoch: 3 	Training Loss: 0.358654
# Batch: 40	Epoch: 3 	Training Loss: 0.297003
# Batch: 60	Epoch: 3 	Training Loss: 0.366692
# Epoch: 3 	Training Loss: 0.355583 	Validation Loss: 0.000103 	Accuracy: 1.000000
#
# FOLD ACCURACY : 1.0

# %%
# import json
# a_file = open("data.json", "w")
# json.dump(results, a_file)
# a_file.close()

# %%
# nSamples = [887, 6130, 480, 317, 972, 101, 128] #of class instances
# normedWeights = [1 - (x / sum(nSamples)) for x in nSamples]
# normedWeights = torch.FloatTensor(normedWeights).to(device)
# Criterion = nn.CrossEntropyLoss(weight=normedWeights)

# %%
# batch_size = 20
# class_sample_count = [10, 1, 20, 3, 4] # dataset has 10 class-1 samples, 1 class-2 samples, etc.
# weights = 1 / torch.Tensor(class_sample_count)
# sampler = torch.utils.data.sampler.WeightedRandomSampler(weights, batch_size)
# trainloader = data_utils.DataLoader(train_dataset, batch_size = batch_size, shuffle=True, sampler = sampler)
