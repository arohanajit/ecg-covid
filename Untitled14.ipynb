# %% [markdown]
# <a href="https://colab.research.google.com/github/arohanajit/ecg-covid/blob/main/Untitled14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as Fl
from torch import optim
from torch.utils.data import DataLoader, TensorDataset, random_split
from torch.utils.data.sampler import SubsetRandomSampler,WeightedRandomSampler
from torchvision.datasets import ImageFolder
import torchvision.transforms as transforms
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import f1_score,precision_score,recall_score
from tqdm import tqdm_notebook
import torchvision
import shutil
train_on_gpu = torch.cuda.is_available()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(train_on_gpu)
# Out:
# True

# %%
# model = torchvision.models.vgg16(pretrained=True)
# model

# %%
# %%capture
if 'data' not in os.listdir():
    # !git clone https://arohanajit:TXhqMLvKoeiUtMy_Xtrz@gitlab.com/arohanajit/ecg-covid.git
    # !unzip ecg-covid/data.zip
    shutil.rmtree("data/covid")
    shutil.rmtree("ecg-covid")

# %%
data_transforms = transforms.Compose([
    transforms.Resize((500,500)),
    transforms.ToTensor()
    ])

# %%
data = ImageFolder('data/',transform=data_transforms)
data.class_to_idx
# Out:
# {'heart': 0, 'normal': 1}

# %%
print(len(os.listdir('data/heart')),len(os.listdir('data/normal')))
test_size = 0.2
print(len(data))
num_train = len(data)
indices = list(range(num_train))
np.random.shuffle(indices)
test_split = int(np.floor((test_size) * num_train))
test_idx, train_idx = indices[:test_split], indices[test_split:]

print(len(test_idx), len(train_idx))

print(train_idx[:5])
# Out:
# 74 859
# 933
# 186 747
# [785, 257, 897, 715, 700]

# %%
def Graphing(train,test):
    plt.plot(train)
    plt.plot(test)
    plt.legend(['Train Loss','Validation Loss'])

# %%
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True
from tqdm.notebook import tqdm

def train(n_epochs, loaders, model, optimizer, scheduler, criterion, train_on_gpu, save_path, batch_size):
    """returns trained model"""
    # initialize tracker for minimum validation loss
    valid_loss_min = np.Inf 
    train = []
    test = []
    accuracy = []
    correct,total = 0,0
    
    for epoch in tqdm(range(1, n_epochs+1)):
        # initialize variables to monitor training and validation loss
        train_loss = 0.0
        valid_loss = 0.0
        valid_min = 9999
        f1_running = 0
        pre_running = 0
        rec_running = 0
        ###################
        # train the model #
        ###################
        model.train()
        for batch_idx, (input, target) in enumerate(loaders['train']):
            # move to GPU
            if train_on_gpu:
                input, target = input.cuda(), target.cuda()
            ## find the loss and update the model parameters accordingly
            ## record the average training loss, using something like
            ## train_loss = train_loss + ((1 / (batch_idx + 1)) * (loss.data - train_loss))
            optimizer.zero_grad()
            out = model(input)
            loss = criterion(out,target)
            loss.backward()
            optimizer.step()
            scheduler.step()
            train_loss = train_loss + ((1 / (batch_idx + 1)) * (loss.data - train_loss))
            if batch_idx%20==0:
                print('Batch: {}\tEpoch: {} \tTraining Loss: {:.6f}'.format(
                batch_idx,
                epoch, 
                train_loss
                ))



        ######################    
        # validate the model #
        ######################
        model.eval()
        correct, total = 0, 0
        score,score1,score2 = 0,0,0
        for batch_idx, (input, target) in enumerate(loaders['test']):
            # move to GPU
            if train_on_gpu:
                input, target = input.cuda(), target.cuda()
            output = model(input)
            loss = criterion(output,target)
            valid_loss = valid_loss + ((1 / (batch_idx + 1)) * (loss.data - valid_loss))
            _, predicted = torch.max(output.data, 1)
            total += target.size(0)
            correct += (predicted == target).sum().item()
            score += f1_score(target.cpu(),predicted.cpu())
            score1 += precision_score(target.cpu(),predicted.cpu())
            score2 += recall_score(target.cpu(),predicted.cpu())
            f1_running = score/(batch_idx+1)
            pre_running = score1/(batch_idx+1)
            rec_running = score2/(batch_idx+1)
            
#             score = classification_report(target.to('cpu'),predicted.to('cpu'))
            # print(predicted[:5],target[:5])

            ## update the average validation loss

            
        train.append(train_loss)
        test.append (valid_loss)
        accuracy.append(correct/total)
        # print training/validation statistics 
        print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f} \tAccuracy: {:.6f}\tF1 Score: {} Precision: {} Recall: {}'.format(
            epoch, 
            train_loss,
            valid_loss,
            correct/total,
            f1_running,
            pre_running,
            rec_running
            ))
        if valid_loss <= valid_loss_min:
            print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
            valid_loss_min,
            valid_loss))
            torch.save(model.state_dict(), save_path)
            valid_loss_min = valid_loss
        
    Graphing(train,test)
    print(f"FOLD ACCURACY : {correct/total}")
    # return trained model
    return model

# %%
class_weights = [74,859]
sample_weights = [0] * len(data)
for idx, (inputs,label) in enumerate(data.imgs):
    class_weight = class_weights[label]
    sample_weights[idx] = class_weight
    
train_sampler = WeightedRandomSampler(sample_weights, num_samples=len(sample_weights), replacement=True)
test_sampler = SubsetRandomSampler(test_idx)

batch_size = 8
loaders = {
    'train': torch.utils.data.DataLoader(data, batch_size=batch_size, sampler=train_sampler),
    'test': torch.utils.data.DataLoader(data, batch_size=batch_size, sampler=test_sampler)
}

# %%
#Model definition
model = torchvision.models.vgg16(pretrained=True)
num_ftrs =  model.classifier[6].in_features
for params in model.features.parameters():
    params.requires_grad = False

model.classifier[6] = nn.Linear(num_ftrs, 2)
model = model.to(device)
# Weights for Cross Entropy Loss
# normedWeights = [1 - (x / sum(class_sample_count)) for x in class_sample_count]
# normedWeights = torch.FloatTensor(normedWeights).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)
scheduler = optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.9)
#Model Train
train(10, loaders, model, optimizer, scheduler, criterion, train_on_gpu, 'model.pt', batch_size)
model.load_state_dict(torch.load('model.pt'))
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Batch: 0	Epoch: 1 	Training Loss: 0.572235
# Batch: 20	Epoch: 1 	Training Loss: 0.073088
# Batch: 40	Epoch: 1 	Training Loss: 0.080764
# Batch: 60	Epoch: 1 	Training Loss: 0.127591
# Batch: 80	Epoch: 1 	Training Loss: 0.119093
# Batch: 100	Epoch: 1 	Training Loss: 0.095515
# Epoch: 1 	Training Loss: 0.091645 	Validation Loss: 0.866678 	Accuracy: 0.908602	F1 Score: 0.9511904761904764 Precision: 0.9114583333333334 Recall: 1.0
# Validation loss decreased (inf --> 0.866678).  Saving model ...
# Batch: 0	Epoch: 2 	Training Loss: 0.000020
# Batch: 20	Epoch: 2 	Training Loss: 0.226654
# Batch: 40	Epoch: 2 	Training Loss: 0.136340
# Batch: 60	Epoch: 2 	Training Loss: 0.126875
# Batch: 80	Epoch: 2 	Training Loss: 0.107663
# Batch: 100	Epoch: 2 	Training Loss: 0.086348
# Epoch: 2 	Training Loss: 0.081289 	Validation Loss: 0.866678 	Accuracy: 0.908602	F1 Score: 0.9511904761904763 Precision: 0.9114583333333334 Recall: 1.0
# Validation loss decreased (0.866678 --> 0.866678).  Saving model ...
# Batch: 0	Epoch: 3 	Training Loss: 0.000012
# Batch: 20	Epoch: 3 	Training Loss: 0.077149
# Batch: 40	Epoch: 3 	Training Loss: 0.100938
# Batch: 60	Epoch: 3 	Training Loss: 0.097915
# Batch: 80	Epoch: 3 	Training Loss: 0.127940
# Batch: 100	Epoch: 3 	Training Loss: 0.116679
# Epoch: 3 	Training Loss: 0.118657 	Validation Loss: 0.866677 	Accuracy: 0.908602	F1 Score: 0.950793650793651 Precision: 0.9114583333333334 Recall: 1.0
# Validation loss decreased (0.866678 --> 0.866677).  Saving model ...
# Batch: 0	Epoch: 4 	Training Loss: 0.000008
# Batch: 20	Epoch: 4 	Training Loss: 0.213744
# Batch: 40	Epoch: 4 	Training Loss: 0.150955
# Batch: 60	Epoch: 4 	Training Loss: 0.118727
# Batch: 80	Epoch: 4 	Training Loss: 0.109478
# Batch: 100	Epoch: 4 	Training Loss: 0.102094
# Epoch: 4 	Training Loss: 0.088136 	Validation Loss: 0.866678 	Accuracy: 0.908602	F1 Score: 0.950793650793651 Precision: 0.9114583333333334 Recall: 1.0
# Batch: 0	Epoch: 5 	Training Loss: 0.000022
# Batch: 20	Epoch: 5 	Training Loss: 0.000021
# Batch: 40	Epoch: 5 	Training Loss: 0.059283
# Batch: 60	Epoch: 5 	Training Loss: 0.066276
# Batch: 80	Epoch: 5 	Training Loss: 0.049916
# Batch: 100	Epoch: 5 	Training Loss: 0.066365
# Epoch: 5 	Training Loss: 0.069490 	Validation Loss: 0.866677 	Accuracy: 0.908602	F1 Score: 0.9494200244200246 Precision: 0.9114583333333334 Recall: 1.0
# Validation loss decreased (0.866677 --> 0.866677).  Saving model ...
# Batch: 0	Epoch: 6 	Training Loss: 0.000017
# Batch: 20	Epoch: 6 	Training Loss: 0.088693
# Batch: 40	Epoch: 6 	Training Loss: 0.077976
# Batch: 60	Epoch: 6 	Training Loss: 0.052417
# Batch: 80	Epoch: 6 	Training Loss: 0.058490
# Batch: 100	Epoch: 6 	Training Loss: 0.111447
# Epoch: 6 	Training Loss: 0.107463 	Validation Loss: 0.866678 	Accuracy: 0.908602	F1 Score: 0.9507020757020759 Precision: 0.9114583333333334 Recall: 1.0
# Batch: 0	Epoch: 7 	Training Loss: 0.000020
# Batch: 20	Epoch: 7 	Training Loss: 0.048632
# Batch: 40	Epoch: 7 	Training Loss: 0.056681
# Batch: 60	Epoch: 7 	Training Loss: 0.060974
# Batch: 80	Epoch: 7 	Training Loss: 0.045924
# Batch: 100	Epoch: 7 	Training Loss: 0.049912
# Epoch: 7 	Training Loss: 0.043089 	Validation Loss: 0.866678 	Accuracy: 0.908602	F1 Score: 0.9511904761904764 Precision: 0.9114583333333334 Recall: 1.0
# Batch: 0	Epoch: 8 	Training Loss: 0.000029
# Batch: 20	Epoch: 8 	Training Loss: 0.000024
# Batch: 40	Epoch: 8 	Training Loss: 0.000023
# Batch: 60	Epoch: 8 	Training Loss: 0.036245
# Batch: 80	Epoch: 8 	Training Loss: 0.039158
# Batch: 100	Epoch: 8 	Training Loss: 0.040604
# Epoch: 8 	Training Loss: 0.035054 	Validation Loss: 0.866679 	Accuracy: 0.908602	F1 Score: 0.9507020757020759 Precision: 0.9114583333333334 Recall: 1.0
# Batch: 0	Epoch: 9 	Training Loss: 0.000032
# Batch: 20	Epoch: 9 	Training Loss: 0.048040
# Batch: 40	Epoch: 9 	Training Loss: 0.058669
# Batch: 60	Epoch: 9 	Training Loss: 0.039441
# Batch: 80	Epoch: 9 	Training Loss: 0.029708
# Batch: 100	Epoch: 9 	Training Loss: 0.023829
# Epoch: 9 	Training Loss: 0.028558 	Validation Loss: 0.978945 	Accuracy: 0.908602	F1 Score: 0.940873015873016 Precision: 0.8958333333333334 Recall: 1.0
# Batch: 0	Epoch: 10 	Training Loss: 0.000029
# Batch: 20	Epoch: 10 	Training Loss: 0.000026
# Batch: 40	Epoch: 10 	Training Loss: 0.078946
# Batch: 60	Epoch: 10 	Training Loss: 0.053069
# Batch: 80	Epoch: 10 	Training Loss: 0.053709
# Batch: 100	Epoch: 10 	Training Loss: 0.043078
# Epoch: 10 	Training Loss: 0.037190 	Validation Loss: 0.866677 	Accuracy: 0.908602	F1 Score: 0.9507936507936509 Precision: 0.9114583333333334 Recall: 1.0
# Validation loss decreased (0.866677 --> 0.866677).  Saving model ...
# FOLD ACCURACY : 0.9086021505376344
# <All keys matched successfully>

# %%
model
